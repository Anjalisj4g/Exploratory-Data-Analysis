# %% [markdown]
# # Exploratory Data Analysis of Employees across various team

# %%
In this section, I use various methods of exploratory data analysis detailing information about of the employees in various team. 
In the given dataset, there are 458 rows and 9 columns. Columns are Name, Team, Number of employees, Position, Age, Height, Weight, College, Salary.
Using these attributes we will find the employee nature on the basis of age, their position or designation, salary etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Employee_Report.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
#Replacing 'Height' column with random numbers

# %%
random_heights = np.random.randint(150, 181, size=len(df))
df['Height'] = random_heights
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     152     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     178     235
# 2     John Holland  Boston Celtics      30       SG   27     167     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     173     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     176     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     180     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     176     256
# 456    Jeff Withey       Utah Jazz      24        C   26     161     231
# 457       Priyanka       Utah Jazz      34        C   25     151     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#To ensure data consistency and integrity

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df['College'].fillna('Unknown',inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     163     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     164     235
# 2     John Holland  Boston Celtics      30       SG   27     174     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     157     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     166     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     161     203
# 454      Raul Neto       Utah Jazz      25       PG   24     164     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     178     256
# 456    Jeff Withey       Utah Jazz      24        C   26     179     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
There were 84 null values in column 'Height' and 11 null values in column 'Salary'. They are filled by 'Unknown'.
Now there are no null values in the dataframe.

# %%
#1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
print("Total Number of Employees =",df['Team'].value_counts().sum())
Teams=df['Team'].value_counts()
Teams
# Out:
# Total Number of Employees = 458
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(Teams, labels=Teams.index, autopct='%1.1f%%',startangle=140)
plt.title('Distribution of Employees Across Teams')
plt.axis('equal')
plt.show()

# %%
From the above graph, most number of employees are in team New Orleans Pelicans with 4.1% of the total number of employees 
followed by team Memphis Grizzlies with 3.9% of the total number of employees.

# %%
#2. Segregate employees based on their positions within the company.

# %%
position_count=df['Position'].value_counts()
position_count
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df,x='Position',palette='rocket')
plt.title('Employees on the basis of Position')
plt.ylabel("Number of Employees")
plt.show()
# Out:
# C:\Users\gokul\AppData\Local\Temp\ipykernel_11360\469288221.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Position',palette='rocket')

# %%
Employees are distributed on the basis of their positions using a Count Plot. From the graph, most number of employees are SG 
followed by PF. The least number of employees are in C position.

# %%
#3. Identify the predominant age group among employees.

# %%
df['Age'].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
age_groups = [18, 25, 30, 35, 42] 

labels = [f'{start}-{end-1}' for start, end in zip(age_groups[:-1], age_groups[1:])]
# Last group goes up to infinity
labels.append(f'{age_groups[-1]}+')

# Cut the ages into age groups
df['Age Group'] = pd.cut(df['Age'], bins=age_groups, labels=labels[:-1], right=False)

# Count occurrences of each age group
age_group_counts = df['Age Group'].value_counts()

# Find the predominant age group
predominant_age_group = age_group_counts.idxmax()
print("Predominant Age Group:", predominant_age_group)
# Out:
# Predominant Age Group: 25-29

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df.dropna(subset=['Age'], inplace=True)

plt.hist(df['Age'], bins=[18, 25, 30, 35, 42],color='yellow',edgecolor='b')
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.title('Histogram of Employee Ages')
plt.show()

# %%
Employees of age group 25-30 are the predominant group followed by age group 18-25. Employees of age group 35-40 are least dominant in the data.

# %%
#4. Discover which team and position have the highest salary expenditure.

# %%
grouped_by_team = df.groupby('Team')['Salary'].sum().reset_index()
grouped_by_position = df.groupby('Position')['Salary'].sum().reset_index()

max_salary_team = grouped_by_team.loc[grouped_by_team['Salary'].idxmax()]
max_salary_position = grouped_by_position.loc[grouped_by_position['Salary'].idxmax()]

print("Team with Highest Salary Expenditure is",max_salary_team['Team'])
print("Total Salary Expenditure:", max_salary_team['Salary'])

print("\nPosition with Highest Salary Expenditure is",max_salary_position['Position'])
print("Total Salary Expenditure:", max_salary_position['Salary'])
# Out:
# Team with Highest Salary Expenditure is Memphis Grizzlies
# Total Salary Expenditure: 511
#
# Position with Highest Salary Expenditure is PF
# Total Salary Expenditure: 2716

# %%
grouped_by_team = df.groupby('Team')['Salary'].sum().reset_index()
grouped_by_position = df.groupby('Position')['Salary'].sum().reset_index()

max_salary_team = grouped_by_team.loc[grouped_by_team['Salary'].idxmax()]
max_salary_position = grouped_by_position.loc[grouped_by_position['Salary'].idxmax()]

plt.figure(figsize=(10, 6))
plt.bar(grouped_by_team['Team'], grouped_by_team['Salary'],color='lightgreen',edgecolor='blue')
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.title('Total Salary Expenditure by Team')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(grouped_by_position['Position'], grouped_by_position['Salary'],color='pink',edgecolor='blue')
plt.xlabel('Position')
plt.ylabel('Total Salary Expenditure')
plt.title('Total Salary Expenditure by Position')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
From the graph, Team with Highest Salary Expenditure is Memphis Grizzlies and team with Least Salary Expenditure is Orlando Magic.
Also, Position with Highest Salary Expenditure is PF and position with least Salary Expenditure is C.

# %%
#5. Investigate if there's any correlation between age and salary, and represent it visually.

# %%
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')
df.dropna(subset=['Salary'], inplace=True)
df1=df.drop(['Name','Team','Position','College','Age Group'],axis='columns')


corr=df1.corr()
sns.heatmap(corr,annot=True,cmap="coolwarm") 
plt.title('Correlation Matrix of Employee Details of ABC Company')
plt.show()

# %%
From the correlation matrix, the correlation coefficient of age and salary is exactly 1. 
This means that there is a strong positive linear relationship between these two variables.
This indicates that as age increases, salary also increases proportionally and vice-versa. 
Through this relationship, we can predict the salary of an employee by knowing his/her age.

# %%
df.describe()
# Out:
#            Number         Age      Height      Weight      Salary
# count  458.000000  458.000000  458.000000  458.000000  458.000000
# mean    17.713974   26.934498  164.735808  221.543668   26.934498
# std     15.966837    4.400128    8.678179   26.343200    4.400128
# min      0.000000   19.000000  150.000000  161.000000   19.000000
# 25%      5.000000   24.000000  158.000000  200.000000   24.000000
# 50%     13.000000   26.000000  164.000000  220.000000   26.000000
# 75%     25.000000   30.000000  172.000000  240.000000   30.000000
# max     99.000000   40.000000  180.000000  307.000000   40.000000

# %%
By using the describe function, it is inferred that median and mean values of 'Number' column is 13 and 17.71 respectively. 
This significant difference is due to the asymmetry in the distribution. 
This is because some team has no or very few employees. Also, there can be many outliers. This variation of data will affect the mean and median value.
In all other cases, median and mean are almost same. This shows symmetric distribution.

# %%
#Analysing Number of Employees in different Age group

# %%
sns.boxplot(df,x='Age Group',y='Number')
# Out:
# <Axes: xlabel='Age Group', ylabel='Number'>

# %%
From the box plot, we can see that there are many data points beyond the whiskers. These are the outliers. Also, the median line is not centered in all
the categories except at the age group 35-41. This shows asymmetry or skewness in the distribution.
Median line of age group 18-24 and 25-29 are almost on the same level. 
The box of age group 25-29 is longer which indicates more dispersion of data. Values are quite different in this category.
Number of employees in age group 25-29 is more.

# %%
#Analysing Salaries of employees in different Age group

# %%
sns.boxplot(df,x='Age Group',y='Salary')
# Out:
# <Axes: xlabel='Age Group', ylabel='Salary'>

# %%
Salary of employees increases significantly with increase in age. 
Highest salary is of age group 35-41 and lowest salary is of age group 18-24
Median line of each category is outside the other boxes. Also, median line is not centered. This shows asymmetry of data.

# %%
#Analysing position of employees in different Age group

# %%
sns.boxplot(df,x='Age Group',y='Position')
# Out:
# <Axes: xlabel='Age Group', ylabel='Position'>

# %%
Position of age group 30-34 are more dispersed.
